# %% [markdown]
# <a href="https://colab.research.google.com/github/urcraft/data_analytics_lecture_notebooks/blob/main/09_rouge_bleu_bertscore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install evaluate rouge-score bert-score sacrebleu
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=d81528df748441a3d7f73009636d18330c7400e395741e1169c31371cae722de
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
import sacrebleu
import evaluate
from bert_score import score

reference = """
Pitch bearing vibration on NW-023 trending upward.
Follow-up in 30 days.
CTV mooring line replaced on Havørn.
"""

prediction = """
Routine inspections at Hvide Sande.
NW-023 pitch bearing elevated vibration.
CTV mooring line replaced.
Downtime reduced by 23%.
"""

references = [reference]
predictions = [prediction]

print("=== BLEU ===")

# sacrebleu expects list of predictions and list of reference lists
bleu = sacrebleu.corpus_bleu(predictions, [references])

print("BLEU score:", round(bleu.score, 2))
print("Precisions:", bleu.precisions)
print("BP (brevity penalty):", round(bleu.bp, 3))

print("\n=== ROUGE ===")

rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions=predictions, references=references)

print("ROUGE-1:", round(rouge_results["rouge1"], 4))
print("ROUGE-2:", round(rouge_results["rouge2"], 4))
print("ROUGE-L:", round(rouge_results["rougeL"], 4))

print("\n=== BERTScore ===")

P, R, F1 = score(predictions, references, lang="en", verbose=False)

print("Precision:", round(P.mean().item(), 4))
print("Recall:", round(R.mean().item(), 4))
print("F1:", round(F1.mean().item(), 4))
# Out:
# === BLEU (SacreBLEU) ===
# BLEU score: 18.33
# Precisions: [43.47826086956522, 18.181818181818183, 14.285714285714286, 10.0]
# BP (brevity penalty): 1.0
#
# === ROUGE ===
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# ...
# ROUGE-1: 0.4615
# ROUGE-2: 0.2703
# ROUGE-L: 0.359
#
# === BERTScore ===
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# ...
